# %%
import pandas as pd
import numpy as np
import seaborn as sns
import torch
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN, SMOTETomek
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
seed = 38
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

train_df = pd.read_csv("mitbih_train.csv", header=None)
test_df = pd.read_csv("mitbih_test.csv", header=None)

x_train = train_df.iloc[:, :-1]
y_train = train_df.iloc[:, -1]
x_test = test_df.iloc[:, :-1]
y_test = test_df.iloc[:, -1]

scaler = MinMaxScaler(feature_range=(0, 1))
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

train_df_scaled = pd.DataFrame(x_train_scaled)
train_df_scaled['label'] = y_train.values

test_df_scaled = pd.DataFrame(x_test_scaled)
test_df_scaled['label'] = y_test.values

ecg_sinteticos = np.load("ecg_sinteticos_clase3.npy")  
labels_sinteticos = np.full((ecg_sinteticos.shape[0],), 3)

ecg_syn_train, ecg_syn_test, y_syn_train, y_syn_test = train_test_split(
    ecg_sinteticos, labels_sinteticos, test_size=0.2, random_state=42, stratify=labels_sinteticos
)

ecg_syn_train_scaled = scaler.transform(ecg_syn_train)
ecg_syn_test_scaled = scaler.transform(ecg_syn_test)

syn_train_df = pd.DataFrame(ecg_syn_train_scaled)
syn_train_df['label'] = y_syn_train  

syn_test_df = pd.DataFrame(ecg_syn_test_scaled)
syn_test_df['label'] = y_syn_test  

train_df_combined = pd.concat([train_df_scaled, syn_train_df], ignore_index=True)
test_df_combined = pd.concat([test_df_scaled, syn_test_df], ignore_index=True)

x_train_0 = train_df_combined[train_df_combined['label'] == 0].iloc[:, :-1]
x_train_1 = train_df_combined[train_df_combined['label'] == 1].iloc[:, :-1]
x_train_2 = train_df_combined[train_df_combined['label'] == 2].iloc[:, :-1]
x_train_3 = train_df_combined[train_df_combined['label'] == 3].iloc[:, :-1]
x_train_4 = train_df_combined[train_df_combined['label'] == 4].iloc[:, :-1]

x_test_0 = test_df_combined[test_df_combined['label'] == 0].iloc[:, :-1]
x_test_1 = test_df_combined[test_df_combined['label'] == 1].iloc[:, :-1]
x_test_2 = test_df_combined[test_df_combined['label'] == 2].iloc[:, :-1]
x_test_3 = test_df_combined[test_df_combined['label'] == 3].iloc[:, :-1]
x_test_4 = test_df_combined[test_df_combined['label'] == 4].iloc[:, :-1]

# %%
ind = 1
normal = x_train_0.iloc[ind].values
anormal_1 = x_test_1.iloc[ind].values
anormal_2 = x_test_2.iloc[ind].values
anormal_3 = x_test_3.iloc[ind].values
anormal_4 = x_test_4.iloc[ind].values

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(normal, label='Normal (Clase 0)')
plt.plot(anormal_1, 'r--', label='Anómalo (Clase 1)')
plt.title("Clase 0 vs Clase 1")
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(normal, label='Normal (Clase 0)')
plt.plot(anormal_2, 'r--', label='Anómalo (Clase 2)')
plt.title("Clase 0 vs Clase 2")
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(normal, label='Normal (Clase 0)')
plt.plot(anormal_3, 'r--', label='Anómalo (Clase 3)')
plt.title("Clase 0 vs Clase 3")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(normal, label='Normal (Clase 0)')
plt.plot(anormal_4, 'r--', label='Anómalo (Clase 4)')
plt.title("Clase 0 vs Clase 4")
plt.legend()

plt.tight_layout()
plt.show()

# %%
dim_entrada = 187
entrada = Input(shape=(dim_entrada,))


encoder = Dense(128, activation='relu')(entrada)
encoder = Dense(64, activation='relu')(encoder)
encoder = Dense(32, activation='relu')(encoder)
encoder = Dense(16, activation='relu')(encoder)  
decoder = Dense(32, activation='relu')(encoder)
decoder = Dense(64, activation='relu')(decoder)
decoder = Dense(128, activation='relu')(decoder)

decoder = Dense(dim_entrada, activation='sigmoid')(decoder)

autoencoder = Model(inputs=entrada, outputs=decoder)

# %%
autoencoder.compile(optimizer='adam', loss='mae')

historia = autoencoder.fit(
    x_train_0, x_train_0,
    epochs=200,
    batch_size=512,
    validation_data=(x_test_0, x_test_0),
    shuffle=True
)
# Out:
# Epoch 1/200
# 142/142 [==============================] - 1s 3ms/step - loss: 0.1428 - val_loss: 0.0656
# Epoch 2/200
# 142/142 [==============================] - 0s 2ms/step - loss: 0.0547 - val_loss: 0.0465
# Epoch 3/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.0429
# Epoch 4/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0394
# Epoch 5/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0383
# Epoch 6/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0371 - val_loss: 0.0368
# Epoch 7/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0359 - val_loss: 0.0356
# Epoch 8/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0348 - val_loss: 0.0342
# Epoch 9/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0340 - val_loss: 0.0335
# Epoch 10/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0328
# Epoch 11/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0325
# Epoch 12/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0320
# Epoch 13/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.0314
# Epoch 14/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0309 - val_loss: 0.0308
# Epoch 15/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0305
# Epoch 16/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0298
# Epoch 17/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0290
# Epoch 18/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0286
# Epoch 19/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0282 - val_loss: 0.0282
# Epoch 20/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0277 - val_loss: 0.0276
# Epoch 21/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0277
# Epoch 22/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0265
# Epoch 23/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0263
# Epoch 24/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0259
# Epoch 25/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0257
# Epoch 26/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0256 - val_loss: 0.0255
# Epoch 27/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0255
# Epoch 28/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0251
# Epoch 29/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0247
# Epoch 30/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0247 - val_loss: 0.0244
# Epoch 31/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0244
# Epoch 32/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0244 - val_loss: 0.0242
# Epoch 33/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0245
# Epoch 34/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0239 - val_loss: 0.0237
# Epoch 35/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0236
# Epoch 36/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0235 - val_loss: 0.0233
# Epoch 37/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0232
# Epoch 38/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0231 - val_loss: 0.0230
# Epoch 39/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 40/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 41/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0231
# Epoch 42/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 43/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0226
# Epoch 44/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0222
# Epoch 45/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0220 - val_loss: 0.0218
# Epoch 46/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0219
# Epoch 47/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 48/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0217
# Epoch 49/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 50/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0214
# Epoch 51/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 52/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0210
# Epoch 53/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0209
# Epoch 54/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.0208
# Epoch 55/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 56/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0206 - val_loss: 0.0206
# Epoch 57/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0205 - val_loss: 0.0204
# Epoch 58/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0203 - val_loss: 0.0204
# Epoch 59/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0203 - val_loss: 0.0213
# Epoch 60/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0204
# Epoch 61/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0206
# Epoch 62/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0202
# Epoch 63/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 64/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0200
# Epoch 65/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0199
# Epoch 66/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0199
# Epoch 67/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0198
# Epoch 68/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0197
# Epoch 69/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0195
# Epoch 70/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0195 - val_loss: 0.0195
# Epoch 71/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 72/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0194
# Epoch 73/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0194
# Epoch 74/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0193
# Epoch 75/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 76/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0191
# Epoch 77/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0191
# Epoch 78/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0189
# Epoch 79/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0189 - val_loss: 0.0191
# Epoch 80/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0189 - val_loss: 0.0194
# Epoch 81/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0192
# Epoch 82/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 83/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 84/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0187
# Epoch 85/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 86/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 87/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0184 - val_loss: 0.0186
# Epoch 88/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 89/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0184 - val_loss: 0.0189
# Epoch 90/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 91/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0183
# Epoch 92/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0182
# Epoch 93/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0183
# Epoch 94/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 95/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 96/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 97/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 98/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 99/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 100/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0179
# Epoch 101/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 102/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0191
# Epoch 103/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 104/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0180
# Epoch 105/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0178
# Epoch 106/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 107/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0176
# Epoch 108/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 109/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0178
# Epoch 110/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0178
# Epoch 111/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 112/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 113/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0175
# Epoch 114/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0174
# Epoch 115/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0173
# Epoch 116/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0174
# Epoch 117/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0176
# Epoch 118/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0172
# Epoch 119/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0171
# Epoch 120/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0174
# Epoch 121/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0174
# Epoch 122/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0173
# Epoch 123/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 124/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 125/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0170
# Epoch 126/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0170
# Epoch 127/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 128/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0170
# Epoch 129/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0168
# Epoch 130/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 131/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0172
# Epoch 132/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0168 - val_loss: 0.0168
# Epoch 133/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0167 - val_loss: 0.0169
# Epoch 134/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0168
# Epoch 135/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0168
# Epoch 136/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0168
# Epoch 137/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0166
# Epoch 138/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 139/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0169
# Epoch 140/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 141/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0169
# Epoch 142/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0167
# Epoch 143/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 144/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0164 - val_loss: 0.0169
# Epoch 145/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 146/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0165
# Epoch 147/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 148/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 149/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0166
# Epoch 150/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0165
# Epoch 151/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0164
# Epoch 152/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0163
# Epoch 153/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 154/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0163
# Epoch 155/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 156/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 157/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0171
# Epoch 158/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 159/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0162
# Epoch 160/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0162
# Epoch 161/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0163
# Epoch 162/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0166
# Epoch 163/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0169
# Epoch 164/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0160
# Epoch 165/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 166/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0161
# Epoch 167/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0161
# Epoch 168/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0160
# Epoch 169/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 170/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0161
# Epoch 171/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0161
# Epoch 172/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0159
# Epoch 173/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0161
# Epoch 174/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0159
# Epoch 175/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 176/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 177/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 178/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0158
# Epoch 179/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 180/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0159
# Epoch 181/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0161
# Epoch 182/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0164
# Epoch 183/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0157
# Epoch 184/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0164
# Epoch 185/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0161
# Epoch 186/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0157
# Epoch 187/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 188/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0160
# Epoch 189/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0158
# Epoch 190/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0163
# Epoch 191/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 192/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 193/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 194/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0168
# Epoch 195/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 196/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 197/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 198/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 199/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 200/200
# 142/142 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0156

# %%
train_losses = historia.history['loss']
val_losses = historia.history['val_loss']

plt.figure(figsize=(10,6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label="Train Loss")
plt.plot(range(1, len(val_losses) + 1), val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss with Early Stopping")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
autoencoder.save('ecg_model_autoencoder.h5')
# Out:
# c:\Users\matia\Documents\codigoCosas\proyectoPortafolio\entrega_2\.venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
reconstructions = autoencoder.predict(x_test_0)

mae = np.mean(np.abs(reconstructions - x_test_0), axis=1)

plt.hist(mae, bins=50)
plt.xlabel('Error absoluto medio (MAE) por muestra')
plt.ylabel('Número de muestras')
plt.title('Distribución del error de reconstrucción')
plt.show()

umbral = 0.03

anomalo_predicho = mae > umbral

for i in range(5):
    print(f"Error MAE muestra {i}: {mae[i]} - Anómalo predicho: {anomalo_predicho[i]}")
# Out:
# 567/567 [==============================] - 0s 498us/step
# Error MAE muestra 0: 0.007452842136696179 - Anómalo predicho: False
# Error MAE muestra 1: 0.020537931587222905 - Anómalo predicho: False
# Error MAE muestra 2: 0.020441733998110584 - Anómalo predicho: False
# Error MAE muestra 3: 0.008930992286359088 - Anómalo predicho: False
# Error MAE muestra 4: 0.03036267780765882 - Anómalo predicho: True

# %%
rec_normal = autoencoder.predict(x_test_0)
rec_anormal = autoencoder.predict(x_test_4)

dato = 10

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(x_test_0.iloc[dato], 'b')          # <-- usar iloc para filas
plt.plot(rec_normal[dato], 'r')
plt.fill_between(np.arange(187), rec_normal[dato], x_test_0.iloc[dato], color='lightcoral')

plt.subplot(1, 2, 2)
plt.plot(x_test_4.iloc[dato], 'b')
plt.plot(rec_anormal[dato], 'r')
plt.fill_between(np.arange(187), rec_anormal[dato], x_test_4.iloc[dato], color='lightcoral')

plt.show()
# Out:
# 567/567 [==============================] - 0s 450us/step
# 51/51 [==============================] - 0s 525us/step

# %%
rec_0 = autoencoder.predict(x_test_0)
rec_1 = autoencoder.predict(x_test_1)
rec_2 = autoencoder.predict(x_test_2)
rec_3 = autoencoder.predict(x_test_3)
rec_4 = autoencoder.predict(x_test_4)

loss_0 = tf.keras.losses.mae(rec_0, x_test_0)
loss_1 = tf.keras.losses.mae(rec_1, x_test_1)
loss_2 = tf.keras.losses.mae(rec_2, x_test_2)
loss_3 = tf.keras.losses.mae(rec_3, x_test_3)
loss_4 = tf.keras.losses.mae(rec_4, x_test_4)

plt.figure(figsize=(15,8))
plt.hist(loss_0[None,:], bins=100, alpha=0.75, label='normales (0)')
plt.hist(loss_1[None,:], bins=100, alpha=0.75, label='abnormales (1)')
plt.hist(loss_2[None,:], bins=100, alpha=0.75, label='abnormales (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, label='abnormales (3)')
plt.hist(loss_4[None,:], bins=100, alpha=0.75, label='abnormales (4)')

plt.axvline(umbral, color='k', linestyle='--', label=f'Threshold {umbral:.3f}')
plt.xlabel('Perdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend()
plt.show()
# Out:
# 567/567 [==============================] - 0s 457us/step
# 18/18 [==============================] - 0s 619us/step
# 46/46 [==============================] - 0s 504us/step
# 68/68 [==============================] - 0s 483us/step
# 51/51 [==============================] - 0s 445us/step

# %%
def calcular_sensitividad(prediccion, titulo):
    TP = np.count_nonzero(~prediccion)
    FN = np.count_nonzero(prediccion)
    sen = 100*(TP/(TP+FN))
    
    print(titulo + ': {:.1f}%' .format(sen))

def calcular_especificidad(prediccion, titulo):
    TN = np.count_nonzero(prediccion)
    FP = np.count_nonzero(~prediccion)
    esp = 100*(TN/(TN+FP))
    
    print(titulo + ': {:.1f}%' .format(esp))
    return esp

def predecir(modelo, datos, umbral):
    datos_np = datos.values.astype(np.float32)  
    reconstrucciones = modelo.predict(datos_np) 
    perdida = tf.keras.losses.mae(reconstrucciones, datos_np)
    return tf.math.less(perdida, umbral)

# %%
pred_0 = predecir(autoencoder, x_test_0, umbral)
pred_1 = predecir(autoencoder, x_test_1, umbral)
pred_2 = predecir(autoencoder, x_test_2, umbral)
pred_3 = predecir(autoencoder, x_test_3, umbral)
pred_4 = predecir(autoencoder, x_test_4, umbral)

esp_0 = calcular_especificidad(pred_0,'Especificidad (cat. 0, normales)')

sen_1 = calcular_sensitividad(pred_1,'Sensitividad (cat. 1, abnormales)')
sen_2 = calcular_sensitividad(pred_2,'Sensitividad (cat. 2, abnormales)')
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. 3, abnormales)')
sen_4 = calcular_sensitividad(pred_4,'Sensitividad (cat. 4, abnormales)')
# Out:
# 567/567 [==============================] - 0s 463us/step
# 18/18 [==============================] - 0s 488us/step
# 46/46 [==============================] - 0s 535us/step
# 68/68 [==============================] - 0s 483us/step
# 51/51 [==============================] - 0s 444us/step
# Especificidad (cat. 0, normales): 93.1%
# Sensitividad (cat. 1, abnormales): 34.4%
# Sensitividad (cat. 2, abnormales): 70.4%
# Sensitividad (cat. 3, abnormales): 0.1%
# Sensitividad (cat. 4, abnormales): 85.0%
